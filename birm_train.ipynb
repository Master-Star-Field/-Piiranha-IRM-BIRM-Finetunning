# %% [markdown]
# **Реализация кастомного Trainer для дообучения модели с применением метода BIRM**

# %%
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModelForTokenClassification
from torch.nn import CrossEntropyLoss
import numpy as np
from collections import defaultdict
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import json
import os
import random
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import gc

# Установка переменной окружения для уменьшения фрагментации памяти
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

COLORS = {
    'blue_grey': '#6699CC',
    'dusky_blue': '#5F84A2',
    'denim': '#5F84A2',
    'light_grey': '#D3D3D3',
    'dark_grey': '#5A5A5A'
}

class PersonalDataDataset(Dataset):
    """
    Датасет для задачи классификации персональных данных.
    Принимает данные в формате CSV и преобразует их в формат, 
    пригодный для обучения модели.
    """
    def __init__(self, dataframe, tokenizer, label_to_id, max_length=512):
        self.df = dataframe.reset_index(drop=True)
        self.tokenizer = tokenizer
        self.label_to_id = label_to_id
        self.id_to_label = {v: k for k, v in label_to_id.items()}
        self.max_length = max_length
        # Группируем данные по формату (это будут наши "среды")
        self.environments = defaultdict(list)
        for idx, row in self.df.iterrows():
            self.environments[row['format_type']].append(idx)
        self.env_list = list(self.environments.keys())

    def __len__(self):
        return len(self.df)
    
    @staticmethod
    def collate_fn(batch):
        """
        Функция для объединения образцов в батч.
        Сделана статичной, чтобы ее можно было передавать в DataLoader напрямую.
        """
        input_ids = torch.stack([item['input_ids'] for item in batch])
        attention_mask = torch.stack([item['attention_mask'] for item in batch])
        labels = torch.stack([item['labels'] for item in batch])
        
        original_tokens = [item['original_tokens'] for item in batch]
        original_labels = [item['original_labels'] for item in batch]
        environments = [item['environment'] for item in batch]
        
        return {
            'input_ids': input_ids,
            'attention_mask': attention_mask,
            'labels': labels,
            'original_tokens': original_tokens,
            'original_labels': original_labels,
            'environments': environments
        }

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        tokens = row['mbert_tokens'].split()
        label_strings = row['mbert_token_classes'].split()

        truncated_tokens = tokens[:self.max_length]
        truncated_label_strings = label_strings[:self.max_length]

        # 2. Преобразование строковых токенов и меток в числовые ID
        input_ids = self.tokenizer.convert_tokens_to_ids(truncated_tokens)
        labels = [self.label_to_id.get(label, self.label_to_id['O']) for label in truncated_label_strings]
        
        attention_mask = [1] * len(input_ids)

        # 4. Дополнение (Padding) до max_length
        padding_length = self.max_length - len(input_ids)
        
        input_ids = input_ids + ([self.tokenizer.pad_token_id] * padding_length)
        labels = labels + ([-100] * padding_length) # -100 игнорируется функцией потерь
        attention_mask = attention_mask + ([0] * padding_length)

        return {
            'input_ids': torch.tensor(input_ids, dtype=torch.long),
            'attention_mask': torch.tensor(attention_mask, dtype=torch.long),
            'labels': torch.tensor(labels, dtype=torch.long),
            'environment': row['format_type'],
            'original_tokens': truncated_tokens,
            'original_labels': truncated_label_strings
        }


class BIRMtrainer:
    """
    Тренер, реализующий обучение с помощью метода Bi-level Invariant Risk Minimization (BIRM).
    """
    def __init__(self, model, tokenizer, num_labels, device='cpu', learning_rate=1e-5, label_to_id=None):
        self.model = model
        self.tokenizer = tokenizer
        self.num_labels = num_labels
        self.device = device
        self.learning_rate = learning_rate
        self.label_to_id = label_to_id
        self.id_to_label = {v: k for k, v in label_to_id.items()} if label_to_id else None
        
        self.optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
        self.loss_func = CrossEntropyLoss(ignore_index=-100)
        
        self.log_history = []
        self.test_metrics_history = []

    def calculate_accuracy(self, logits, labels):
        predictions = torch.argmax(logits, dim=-1)
        mask = labels != -100
        if mask.sum() == 0:
            return 0.0
        correct = (predictions[mask] == labels[mask]).sum().item()
        total = mask.sum().item()
        return correct / total if total > 0 else 0.0

    def train_step(self, environment_batches, current_lambda=1.0):
        self.optimizer.zero_grad()
        
        env_losses = []
        total_erm_loss = torch.tensor(0.0, device=self.device)
        total_accuracy = 0.0
        num_environments = len(environment_batches)

        # 1. Проход по всем средам для сбора потерь
        for batch in environment_batches:
            input_ids = batch['input_ids'].to(self.device)
            attention_mask = batch['attention_mask'].to(self.device)
            labels = batch['labels'].to(self.device)
            
            outputs = self.model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                labels=labels # labels нужны для автоматического расчета loss
            )
            
            clean_logits = outputs.logits
            
            # --- Расчет составляющих лосса для BIRM ---

            # 1.1 Потеря для компонента штрафа (считается на "чистых" логитах)
            clean_loss = outputs.loss
            env_losses.append(clean_loss)

            #Потеря для основного компонента ERM (считается на "зашумленных" логитах)
            # Добавляем к логитам шум из нормального распределения N(0, 1)
            noise = torch.randn_like(clean_logits, device=self.device)
            noisy_logits = clean_logits + noise
            
            erm_loss = self.loss_func(
                noisy_logits.view(-1, self.num_labels), 
                labels.view(-1)
            )
            total_erm_loss += erm_loss
            
            # Точность считаем на "чистых" логитах для адекватной оценки
            total_accuracy += self.calculate_accuracy(clean_logits, labels)
            
        # Расчет итоговой функции потерь BIRM
        if num_environments > 0:
            # Основная составляющая (средняя ERM потеря по средам)
            avg_erm_loss = total_erm_loss / num_environments

            #Составляющая штрафа (дисперсия потерь по средам)
            penalty = torch.tensor(0.0, device=self.device)
            if num_environments > 1:
                losses_tensor = torch.stack(env_losses)
                mean_loss = losses_tensor.mean()
                # Штраф = sum((loss_i - mean_loss)^2)
                penalty = torch.sum((losses_tensor - mean_loss) ** 2)

            # Итоговый лосс
            combined_loss = avg_erm_loss + current_lambda * penalty
            
            combined_loss.backward()
            self.optimizer.step()
            
            avg_accuracy = total_accuracy / num_environments
        else:
            avg_erm_loss = torch.tensor(0.0)
            penalty = torch.tensor(0.0)
            avg_accuracy = 0.0

        return {
            'loss': avg_erm_loss.item(),
            'accuracy': avg_accuracy,
            'penalty': penalty.item()
        }
    
    def train(self, dataset, test_dataset=None, epochs=3, batch_size=8, lambda_initial=1.0, lambda_final=1000.0):
        if torch.cuda.is_available():
            print("Очистка CUDA кэша перед началом обучения...")
            torch.cuda.empty_cache()
            gc.collect()

        env_loaders = {}
        for env_name, indices in dataset.environments.items():
            if len(indices) > 0:
                env_subset = torch.utils.data.Subset(dataset, indices)
                env_loaders[env_name] = DataLoader(
                    env_subset, 
                    batch_size=batch_size, 
                    shuffle=True,
                    collate_fn=PersonalDataDataset.collate_fn,
                    num_workers=2,
                    pin_memory=True
                )
        
        if not env_loaders:
            print("Нет данных для обучения.")
            return
            
        steps_per_epoch = max(len(loader) for loader in env_loaders.values())
        print(f"Найдено сред: {len(env_loaders)}. Шагов в эпохе: {steps_per_epoch}")

        self.model.train()
        
        for epoch in range(epochs):
            # Адаптивный параметр lambda (линейный рост)
            progress = epoch / (epochs - 1) if epochs > 1 else 1.0
            current_lambda = lambda_initial + (lambda_final - lambda_initial) * progress
            
            print(f"\n{'='*20} Эпоха {epoch + 1}/{epochs} (λ={current_lambda:.2f}) {'='*20}")
            
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
                gc.collect()
            
            env_iterators = {name: iter(loader) for name, loader in env_loaders.items()}
            
            epoch_losses, epoch_accuracies, epoch_penalties = [], [], []

            for step in range(steps_per_epoch):
                environment_batches = []
                for name, iterator in env_iterators.items():
                    try:
                        batch = next(iterator)
                        environment_batches.append(batch)
                    except StopIteration:
                        env_iterators[name] = iter(env_loaders[name])
                        batch = next(env_iterators[name])
                        environment_batches.append(batch)

                result = self.train_step(environment_batches, current_lambda)
                epoch_losses.append(result['loss'])
                epoch_accuracies.append(result['accuracy'])
                epoch_penalties.append(result['penalty'])
                
                if (step + 1) % 50 == 0:
                    print(f"  Эпоха {epoch+1}, Шаг {step+1}/{steps_per_epoch}: "
                          f"Loss={result['loss']:.4f}, "
                          f"Acc={result['accuracy']:.4f}, "
                          f"Penalty={result['penalty']:.4f}")

            avg_loss = np.mean(epoch_losses)
            avg_accuracy = np.mean(epoch_accuracies)
            avg_penalty = np.mean(epoch_penalties)
            
            self.log_history.append({
                'epoch': epoch + 1, 'loss': avg_loss,
                'accuracy': avg_accuracy, 'penalty': avg_penalty
            })
            print(f"Конец эпохи {epoch + 1}: Avg Loss: {avg_loss:.4f}, Avg Acc: {avg_accuracy:.4f}, Avg Penalty: {avg_penalty:.4f}")

            if test_dataset:
                test_metrics = self.evaluate_model(test_dataset, batch_size)
                self.test_metrics_history.append(test_metrics)
                print(f"Тестовые метрики: Loss={test_metrics['loss']:.4f}, Acc={test_metrics['accuracy']:.4f}, F1={test_metrics['f1']:.4f}")
                self.print_random_test_sample(test_dataset)

        if self.test_metrics_history:
            self.plot_metrics()

    def evaluate_model(self, dataset, batch_size=16):
        self.model.eval()
        all_predictions, all_labels = [], []
        total_loss, num_batches = 0.0, 0
        
        test_loader = DataLoader(
            dataset, batch_size=batch_size, shuffle=False,
            collate_fn=PersonalDataDataset.collate_fn
        )
        
        with torch.no_grad():
            for batch in test_loader:
                input_ids = batch['input_ids'].to(self.device)
                attention_mask = batch['attention_mask'].to(self.device)
                labels = batch['labels'].to(self.device)
                
                outputs = self.model(input_ids, attention_mask=attention_mask, labels=labels)
                
                total_loss += outputs.loss.item()
                num_batches += 1
                
                predictions = torch.argmax(outputs.logits, dim=-1)
                mask = labels != -100
                all_predictions.extend(predictions[mask].cpu().numpy())
                all_labels.extend(labels[mask].cpu().numpy())
        
        self.model.train()
        
        unique_labels = list(set(all_labels))
        precision, recall, f1, _ = precision_recall_fscore_support(
            all_labels, all_predictions, labels=unique_labels, average='weighted', zero_division=0
        )
        return {
            'loss': total_loss / num_batches if num_batches > 0 else 0.0,
            'accuracy': accuracy_score(all_labels, all_predictions),
            'precision': precision, 'recall': recall, 'f1': f1
        }
        
    def print_random_test_sample(self, test_dataset):
        if not test_dataset or not self.id_to_label:
            print("Тестовый датасет недоступен или отсутствует отображение меток")
            return
            
        sample_idx = random.randint(0, len(test_dataset) - 1)
        sample = test_dataset[sample_idx]
        
        input_ids = sample['input_ids'].unsqueeze(0).to(self.device)
        attention_mask = sample['attention_mask'].unsqueeze(0).to(self.device)
        true_labels_padded = sample['labels']
        original_tokens = sample['original_tokens']
        
        self.model.eval()
        with torch.no_grad():
            logits = self.model(input_ids=input_ids, attention_mask=attention_mask).logits
            predictions_padded = torch.argmax(logits, dim=-1).squeeze(0)
        self.model.train()
        
        print(f"\n{'='*30} СЛУЧАЙНЫЙ ТЕСТОВЫЙ ПРИМЕР {'='*30}")
        print(f"{'Токен':<25} | {'Истинная метка':<20} | {'Предсказание':<20}")
        print("-" * 70)
        
        for i, token in enumerate(original_tokens):
            true_label_id = true_labels_padded[i].item()
            pred_label_id = predictions_padded[i].item()

            true_label_str = self.id_to_label.get(true_label_id, "N/A")
            pred_label_str = self.id_to_label.get(pred_label_id, "N/A")

            marker = " ❌" if true_label_str != pred_label_str else ""
            print(f"{token:<25} | {true_label_str:<20} | {pred_label_str:<20}{marker}")
            
        print(f"{'='*80}\n")
    
    def plot_metrics(self, save_path='training_plots.pdf'):
        if not self.log_history or not self.test_metrics_history:
            print("Недостаточно данных для построения графиков")
            return

        epochs = [entry['epoch'] for entry in self.log_history]
        train_losses = [entry['loss'] for entry in self.log_history]
        train_accuracies = [entry['accuracy'] for entry in self.log_history]
        test_losses = [entry['loss'] for entry in self.test_metrics_history]
        test_accuracies = [entry['accuracy'] for entry in self.test_metrics_history]
        test_precisions = [entry['precision'] for entry in self.test_metrics_history]
        test_recalls = [entry['recall'] for entry in self.test_metrics_history]
        test_f1s = [entry['f1'] for entry in self.test_metrics_history]

        plt.style.use('seaborn-v0_8-whitegrid')
        figs = []

        # 1. Loss
        fig1, ax1 = plt.subplots(figsize=(8, 5))
        ax1.plot(epochs, train_losses, color=COLORS['denim'], marker='o', linestyle='-', label='Train Loss')
        ax1.plot(epochs, test_losses, color=COLORS['blue_grey'], marker='X', linestyle='--', label='Test Loss')
        ax1.set_title('Loss', fontsize=14)
        ax1.set_xlabel('Epoch', fontsize=12)
        ax1.set_ylabel('Loss', fontsize=12)
        ax1.legend()
        figs.append(fig1)

        # 2. Accuracy
        fig2, ax2 = plt.subplots(figsize=(8, 5))
        ax2.plot(epochs, train_accuracies, color=COLORS['denim'], marker='o', linestyle='-', label='Train Accuracy')
        ax2.plot(epochs, test_accuracies, color=COLORS['blue_grey'], marker='X', linestyle='--', label='Test Accuracy')
        ax2.set_title('Accuracy', fontsize=14)
        ax2.set_xlabel('Epoch', fontsize=12)
        ax2.set_ylabel('Accuracy', fontsize=12)
        ax2.legend()
        figs.append(fig2)

        # 3. Precision
        fig3, ax3 = plt.subplots(figsize=(8, 5))
        ax3.plot(epochs, test_precisions, color=COLORS['dusky_blue'], marker='s', linestyle='-', label='Test Precision')
        ax3.set_title('Precision', fontsize=14)
        ax3.set_xlabel('Epoch', fontsize=12)
        ax3.set_ylabel('Precision', fontsize=12)
        ax3.legend()
        figs.append(fig3)

        # 4. Recall
        fig4, ax4 = plt.subplots(figsize=(8, 5))
        ax4.plot(epochs, test_recalls, color=COLORS['denim'], marker='^', linestyle='-', label='Test Recall')
        ax4.set_title('Recall', fontsize=14)
        ax4.set_xlabel('Epoch', fontsize=12)
        ax4.set_ylabel('Recall', fontsize=12)
        ax4.legend()
        figs.append(fig4)

        # 5. F1
        fig5, ax5 = plt.subplots(figsize=(8, 5))
        ax5.plot(epochs, test_f1s, color=COLORS['blue_grey'], marker='D', linestyle='-', label='Test F1-score')
        ax5.set_title('F1-score', fontsize=14)
        ax5.set_xlabel('Epoch', fontsize=12)
        ax5.set_ylabel('F1-score', fontsize=12)
        ax5.legend()
        figs.append(fig5)

        with PdfPages(save_path) as pdf:
            for fig in figs:
                pdf.savefig(fig)
        plt.show()
        print(f"Графики сохранены в {save_path}")

def get_base_labels(label_strings):
    base_labels = set()
    for label in label_strings:
        if label.startswith('B-') or label.startswith('I-'):
            base_labels.add(label[2:])
        else:
            base_labels.add(label)
    return base_labels

def main():
    print("Загрузка данных...")
    try:
        df = pd.read_csv('generated_pii_dataset_structured.csv')
    except FileNotFoundError:
        print("Ошибка: Файл 'generated_pii_dataset_structured.csv' не найден.")
        print("Пожалуйста, убедитесь, что файл находится в той же директории, что и скрипт, или укажите полный путь.")
        return

    all_base_labels = set()
    train_df = df[df['split'] == 'train'].copy()
    for labels_str in train_df['mbert_token_classes']:
        if isinstance(labels_str, str):
            all_base_labels.update(get_base_labels(labels_str.split()))

    unique_base_labels = sorted([l for l in all_base_labels if l != 'O'])
    full_label_to_id = {'O': 0}
    current_id = 1
    for base_label in unique_base_labels:
        full_label_to_id[f'B-{base_label}'] = current_id
        current_id += 1
        full_label_to_id[f'I-{base_label}'] = current_id
        current_id += 1
    
    print(f"Полный словарь меток ({len(full_label_to_id)}): {full_label_to_id}")

    model_name = "iiiorg/piiranha-v1-detect-personal-information"
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForTokenClassification.from_pretrained(
        model_name,
        num_labels=len(full_label_to_id),
        id2label={v: k for k, v in full_label_to_id.items()},
        label2id=full_label_to_id,
        ignore_mismatched_sizes=True
    )
    
    print("Создание датасетов...")
    train_dataset = PersonalDataDataset(train_df, tokenizer, full_label_to_id)
    test_df = df[df['split'] == 'test'].copy()
    test_dataset = PersonalDataDataset(test_df, tokenizer, full_label_to_id) if len(test_df) > 0 else None

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    #device = torch.device('cpu')
    model = model.to(device)
    print(f"Используется устройство: {device}")

    trainer = BIRMtrainer(model, tokenizer, len(full_label_to_id), device=device, label_to_id=full_label_to_id)
    
    print("Начало обучения по методу BIRM...")

    trainer.train(
        train_dataset, 
        test_dataset=test_dataset, 
        epochs=20, 
        batch_size=12, 
        lambda_initial=1.0, 
        lambda_final=1000.0
    )
    
    print("Сохранение модели...")
    save_dir = './trained_model_birm' # Изменено имя папки
    os.makedirs(save_dir, exist_ok=True)
    model.save_pretrained(save_dir)
    tokenizer.save_pretrained(save_dir)
    with open(os.path.join(save_dir, 'label_to_id.json'), 'w', encoding='utf-8') as f:
        json.dump(full_label_to_id, f, ensure_ascii=False, indent=4)

    print("Обучение завершено!")

if __name__ == "__main__":
    main()
# Out:
# Загрузка данных...
# Полный словарь меток (45): {'O': 0, 'B-ACCOUNTNUM': 1, 'I-ACCOUNTNUM': 2, 'B-ADDRESS': 3, 'I-ADDRESS': 4, 'B-BUILDINGNUM': 5, 'I-BUILDINGNUM': 6, 'B-CITY': 7, 'I-CITY': 8, 'B-CREDITCARDNUMBER': 9, 'I-CREDITCARDNUMBER': 10, 'B-DATEOFBIRTH': 11, 'I-DATEOFBIRTH': 12, 'B-DRIVERLICENSENUM': 13, 'I-DRIVERLICENSENUM': 14, 'B-EMAIL': 15, 'I-EMAIL': 16, 'B-GIVENNAME': 17, 'I-GIVENNAME': 18, 'B-IDCARDNUM': 19, 'I-IDCARDNUM': 20, 'B-IP_ADDRESS': 21, 'I-IP_ADDRESS': 22, 'B-PASSWORD': 23, 'I-PASSWORD': 24, 'B-PERSON': 25, 'I-PERSON': 26, 'B-PHONE': 27, 'I-PHONE': 28, 'B-SOCIALNUM': 29, 'I-SOCIALNUM': 30, 'B-STREET': 31, 'I-STREET': 32, 'B-SURNAME': 33, 'I-SURNAME': 34, 'B-TAXNUM': 35, 'I-TAXNUM': 36, 'B-TELEPHONENUM': 37, 'I-TELEPHONENUM': 38, 'B-URL': 39, 'I-URL': 40, 'B-USERNAME': 41, 'I-USERNAME': 42, 'B-ZIPCODE': 43, 'I-ZIPCODE': 44}
# Some weights of DebertaV2ForTokenClassification were not initialized from the model checkpoint at iiiorg/piiranha-v1-detect-personal-information and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([18]) in the checkpoint and torch.Size([45]) in the model instantiated
# - classifier.weight: found shape torch.Size([18, 768]) in the checkpoint and torch.Size([45, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Создание датасетов...
# Используется устройство: cuda
# Начало обучения по методу BIRM...
# Очистка CUDA кэша перед началом обучения...
# Найдено сред: 4. Шагов в эпохе: 68
#
# ==================== Эпоха 1/20 (λ=1.00) ====================
#   Эпоха 1, Шаг 50/68: Loss=1.3516, Acc=0.7608, Penalty=0.0234
# Конец эпохи 1: Avg Loss: 1.9105, Avg Acc: 0.6823, Avg Penalty: 0.0986
# Тестовые метрики: Loss=0.7792, Acc=0.8432, F1=0.7959
#
# ============================== СЛУЧАЙНЫЙ ТЕСТОВЫЙ ПРИМЕР ==============================
# Токен                     | Истинная метка       | Предсказание
# ----------------------------------------------------------------------
# ▁AC                       | O                    | O
# COUNT                     | O                    | O
# NUM                       | O                    | O
# ▁                         | O                    | O
# =                         | O                    | O
# ▁N                        | B-ACCOUNTNUM         | I-ACCOUNTNUM         ❌
# UND                       | I-ACCOUNTNUM         | I-ACCOUNTNUM
# 428                       | I-ACCOUNTNUM         | I-ACCOUNTNUM
# 9069                      | I-ACCOUNTNUM         | I-ACCOUNTNUM
# 978                       | I-ACCOUNTNUM         | I-ACCOUNTNUM
# 492                       | I-ACCOUNTNUM         | I-ACCOUNTNUM
# 2                         | I-ACCOUNTNUM         | I-ACCOUNTNUM
# ▁                         | O                    | O
# BUILD                     | O                    | O
# ING                       | O                    | O
# NUM                       | O                    | O
# ▁                         | O                    | O
# =                         | O                    | O
# ▁29                       | B-BUILDINGNUM        | O                    ❌
# 14                        | I-BUILDINGNUM        | O                    ❌
# ▁CITY                     | O                    | O
# ▁                         | O                    | O
# =                         | O                    | O
# ▁                         | B-CITY               | I-ADDRESS            ❌
# Sandra                    | I-CITY               | I-ADDRESS            ❌
# shire                     | I-CITY               | I-ADDRESS            ❌
# ▁C                        | O                    | O
# REDIT                     | O                    | O
# CARD                      | O                    | O
# N                         | O                    | O
# UMBER                     | O                    | O
# ▁                         | O                    | O
# =                         | O                    | O
# ▁415                      | B-CREDITCARDNUMBER   | I-CREDITCARDNUMBER   ❌
# 2750                      | I-CREDITCARDNUMBER   | I-CREDITCARDNUMBER
# 955                       | I-CREDITCARDNUMBER   | I-CREDITCARDNUMBER
# 340                       | I-CREDITCARDNUMBER   | I-CREDITCARDNUMBER
# 433                       | I-CREDITCARDNUMBER   | I-CREDITCARDNUMBER
# ▁                         | O                    | O
# DATE                      | O                    | O
# OF                        | O                    | O
# BIR                       | O                    | O
# TH                        | O                    | O
# ▁                         | O                    | O
# =                         | O                    | O
# ▁2011                     | B-DATEOFBIRTH        | I-EMAIL              ❌
# -04-11                    | I-DATEOFBIRTH        | I-DRIVERLICENSENUM   ❌
# ▁                         | O                    | O
# DRIVER                    | O                    | O
# LIC                       | O                    | O
# ENSE                      | O                    | O
# NUM                       | O                    | O
# ▁                         | O                    | O
# =                         | O                    | O
# ▁259                      | B-DRIVERLICENSENUM   | I-EMAIL              ❌
# -                         | I-DRIVERLICENSENUM   | I-EMAIL              ❌
# L                         | I-DRIVERLICENSENUM   | I-EMAIL              ❌
# XS                        | I-DRIVERLICENSENUM   | I-EMAIL              ❌
# ▁                         | O                    | O
# EMAIL                     | O                    | O
# ▁                         | O                    | O
# =                         | O                    | O
# ▁maria                    | B-EMAIL              | I-EMAIL              ❌
# har                       | I-EMAIL              | I-EMAIL
# ris                       | I-EMAIL              | I-EMAIL
# @                         | I-EMAIL              | I-EMAIL
# example                   | I-EMAIL              | I-EMAIL
# .                         | I-EMAIL              | I-EMAIL
# net                       | I-EMAIL              | I-EMAIL
# ▁GI                       | O                    | O
# VEN                       | O                    | O
# NAME                      | O                    | O
# ▁                         | O                    | O
# =                         | O                    | O
# ▁Jacob                    | B-GIVENNAME          | I-EMAIL              ❌
# ▁ID                       | O                    | O
# CARD                      | O                    | O
# NUM                       | O                    | O
# ▁                         | O                    | O
# =                         | O                    | O
# ▁326                      | B-IDCARDNUM          | I-IDCARDNUM          ❌
# -74                       | I-IDCARDNUM          | I-IDCARDNUM
# -                         | I-IDCARDNUM          | I-IDCARDNUM
# 4547                      | I-IDCARDNUM          | I-IDCARDNUM
# ▁                         | O                    | O
# PASSWORD                  | O                    | O
# ▁                         | O                    | O
# =                         | O                    | O
# ▁                         | B-PASSWORD           | I-PASSWORD           ❌
# n                         | I-PASSWORD           | I-PASSWORD
# +5                        | I-PASSWORD           | I-PASSWORD
# V                         | I-PASSWORD           | I-PASSWORD
# vw                        | I-PASSWORD           | I-PASSWORD
# Wi                        | I-PASSWORD           | I-PASSWORD
# y                         | I-PASSWORD           | I-PASSWORD
# X                         | I-PASSWORD           | I-PASSWORD
# ▁                         | O                    | O
# SOCIAL                    | O                    | O
# NUM                       | O                    | O
# ▁                         | O                    | O
# =                         | O                    | O
# ▁                         | B-SOCIALNUM          | I-IP_ADDRESS         ❌
# 834                       | I-SOCIALNUM          | I-IP_ADDRESS         ❌
# -25                       | I-SOCIALNUM          | I-IP_ADDRESS         ❌
# -4                        | I-SOCIALNUM          | I-IP_ADDRESS         ❌
# 296                       | I-SOCIALNUM          | I-IP_ADDRESS         ❌
# ▁ST                       | O                    | O
# REET                      | O                    | O
# ▁                         | O                    | O
# =                         | O                    | O
# ▁Lopez                    | B-STREET             | I-ADDRESS            ❌
# ▁Stream                   | I-STREET             | I-ADDRESS            ❌
# ▁SUR                      | O                    | O
# NAME                      | O                    | O
# ▁                         | O                    | O
# =                         | O                    | O
# ▁                         | B-SURNAME            | I-ADDRESS            ❌
# Bryan                     | I-SURNAME            | I-ADDRESS            ❌
# t                         | I-SURNAME            | I-ADDRESS            ❌
# ▁                         | O                    | O
# TAX                       | O                    | O
# NUM                       | O                    | O
# ▁                         | O                    | O
# =                         | O                    | O
# ▁                         | B-TAXNUM             | I-IDCARDNUM          ❌
# 948                       | I-TAXNUM             | I-IDCARDNUM          ❌
# -                         | I-TAXNUM             | I-IDCARDNUM          ❌
# 88                        | I-TAXNUM             | I-IDCARDNUM          ❌
# -                         | I-TAXNUM             | I-IDCARDNUM          ❌
# 2204                      | I-TAXNUM             | I-IDCARDNUM          ❌
# ▁TELE                     | O                    | O
# PHONE                     | O                    | O
# NUM                       | O                    | O
# ▁                         | O                    | O
# =                         | O                    | O
# ▁(4                       | B-TELEPHONENUM       | I-TELEPHONENUM       ❌
# 36)                       | I-TELEPHONENUM       | I-TELEPHONENUM
# 992                       | I-TELEPHONENUM       | I-TELEPHONENUM
# -                         | I-TELEPHONENUM       | I-TELEPHONENUM
# 0971                      | I-TELEPHONENUM       | I-TELEPHONENUM
# x                         | I-TELEPHONENUM       | I-TELEPHONENUM
# 198                       | I-TELEPHONENUM       | I-TELEPHONENUM
# ▁                         | O                    | O
# USER                      | O                    | O
# NAME                      | O                    | O
# ▁                         | O                    | O
# =                         | O                    | O
# ▁                         | B-USERNAME           | I-EMAIL              ❌
# taylor                    | I-USERNAME           | I-EMAIL              ❌
# ste                       | I-USERNAME           | I-EMAIL              ❌
# phani                     | I-USERNAME           | I-EMAIL              ❌
# e                         | I-USERNAME           | I-EMAIL              ❌
# ▁                         | O                    | O
# ZIP                       | O                    | O
# CODE                      | O                    | O
# ▁                         | O                    | O
# =                         | O                    | O
# ▁07                       | B-ZIPCODE            | I-IDCARDNUM          ❌
# 490                       | I-ZIPCODE            | I-CREDITCARDNUMBER   ❌
# ================================================================================
#
#
# ==================== Эпоха 2/20 (λ=53.58) ====================
#   Эпоха 2, Шаг 50/68: Loss=1.2939, Acc=0.7945, Penalty=0.0000
# Конец эпохи 2: Avg Loss: 1.3217, Avg Acc: 0.7938, Avg Penalty: 0.0086
# Тестовые метрики: Loss=0.8808, Acc=0.8137, F1=0.7733
#
# ============================== СЛУЧАЙНЫЙ ТЕСТОВЫЙ ПРИМЕР ==============================
# Токен                     | Истинная метка       | Предсказание
# ----------------------------------------------------------------------
# ▁                         | O                    | O
# timestamp                 | O                    | O
# ,                         | O                    | O
# client                    | O                    | O
# _                         | O                    | O
# ip                        | O                    | O
# ,                         | O                    | O
# request                   | O                    | O
# ,                         | O                    | O
# request                   | O                    | O
# ed                        | O                    | O
# _                         | O                    | O
# url                       | O                    | O
# ,                         | O                    | O
# user                      | O                    | O
# _                         | O                    | O
# email                     | O                    | O
# ,                         | O                    | O
# status                    | O                    | O
# ▁1976                     | O                    | O
# -03-14                    | O                    | O
# T                         | O                    | O
# 0                         | O                    | O
# 2:41                      | O                    | O
# :18                       | O                    | O
# .70                       | O                    | O
# 5645                      | O                    | O
# ▁                         | O                    | O
# ,                         | O                    | O
# ▁3                        | B-IP_ADDRESS         | O                    ❌
# 5.45                      | I-IP_ADDRESS         | O                    ❌
# .                         | I-IP_ADDRESS         | O                    ❌
# 145.                      | I-IP_ADDRESS         | O                    ❌
# 17                        | I-IP_ADDRESS         | O                    ❌
# ▁                         | O                    | O
# ,                         | O                    | O
# ▁GET                      | O                    | O
# ▁                         | O                    | O
# ,                         | O                    | O
# ▁https                    | B-URL                | O                    ❌
# ://                       | I-URL                | I-TELEPHONENUM       ❌
# www                       | I-URL                | I-TELEPHONENUM       ❌
# .                         | I-URL                | I-TELEPHONENUM       ❌
# e                         | I-URL                | I-TELEPHONENUM       ❌
# wing                      | I-URL                | I-TELEPHONENUM       ❌
# .                         | I-URL                | I-TELEPHONENUM       ❌
# com                       | I-URL                | I-TELEPHONENUM       ❌
# /                         | I-URL                | I-TELEPHONENUM       ❌
# ▁                         | O                    | O
# ,                         | O                    | O
# ▁                         | B-EMAIL              | I-EMAIL              ❌
# angela                    | I-EMAIL              | I-EMAIL
# hall                      | I-EMAIL              | I-EMAIL
# @                         | I-EMAIL              | I-EMAIL
# example                   | I-EMAIL              | I-EMAIL
# .                         | I-EMAIL              | I-EMAIL
# net                       | I-EMAIL              | I-EMAIL
# ▁                         | O                    | O
# ,                         | O                    | O
# ▁S                        | O                    | O
# UC                        | O                    | O
# CESS                      | O                    | O
# ================================================================================
#
#
# ==================== Эпоха 3/20 (λ=106.16) ====================
#   Эпоха 3, Шаг 50/68: Loss=1.0839, Acc=0.8095, Penalty=0.0004
# Конец эпохи 3: Avg Loss: 1.1557, Avg Acc: 0.7992, Avg Penalty: 0.0017
# Тестовые метрики: Loss=0.8129, Acc=0.8142, F1=0.7721
#
# ============================== СЛУЧАЙНЫЙ ТЕСТОВЫЙ ПРИМЕР ==============================
# Токен                     | Истинная метка       | Предсказание
# ----------------------------------------------------------------------
# ▁<                        | O                    | O
# ▁data                     | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁AC                       | O                    | O
# COUNT                     | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁LP                       | B-ACCOUNTNUM         | O                    ❌
# NK                        | I-ACCOUNTNUM         | O                    ❌
# 8                         | I-ACCOUNTNUM         | O                    ❌
# 3868                      | I-ACCOUNTNUM         | O                    ❌
# 756                       | I-ACCOUNTNUM         | O                    ❌
# 967                       | I-ACCOUNTNUM         | O                    ❌
# 385                       | I-ACCOUNTNUM         | O                    ❌
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁AC                       | O                    | O
# COUNT                     | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# BUILD                     | O                    | O
# ING                       | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁365                      | B-BUILDINGNUM        | O                    ❌
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁                         | O                    | O
# BUILD                     | O                    | O
# ING                       | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁CITY                     | O                    | O
# ▁>                        | O                    | O
# ▁                         | B-CITY               | I-ADDRESS            ❌
# Aaron                     | I-CITY               | I-ADDRESS            ❌
# stad                      | I-CITY               | I-ADDRESS            ❌
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁CITY                     | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁C                        | O                    | O
# REDIT                     | O                    | O
# CARD                      | O                    | O
# N                         | O                    | O
# UMBER                     | O                    | O
# ▁>                        | O                    | O
# ▁435                      | B-CREDITCARDNUMBER   | O                    ❌
# 2195                      | I-CREDITCARDNUMBER   | O                    ❌
# 580                       | I-CREDITCARDNUMBER   | O                    ❌
# 718                       | I-CREDITCARDNUMBER   | O                    ❌
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁C                        | O                    | O
# REDIT                     | O                    | O
# CARD                      | O                    | O
# N                         | O                    | O
# UMBER                     | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# DATE                      | O                    | O
# OF                        | O                    | O
# BIR                       | O                    | O
# TH                        | O                    | O
# ▁>                        | O                    | O
# ▁1931                     | B-DATEOFBIRTH        | O                    ❌
# -10-21                    | I-DATEOFBIRTH        | O                    ❌
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁                         | O                    | O
# DATE                      | O                    | O
# OF                        | O                    | O
# BIR                       | O                    | O
# TH                        | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# DRIVER                    | O                    | O
# LIC                       | O                    | O
# ENSE                      | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁J                        | B-DRIVERLICENSENUM   | O                    ❌
# GV                        | I-DRIVERLICENSENUM   | O                    ❌
# ▁121                      | I-DRIVERLICENSENUM   | O                    ❌
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁                         | O                    | O
# DRIVER                    | O                    | O
# LIC                       | O                    | O
# ENSE                      | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# EMAIL                     | O                    | O
# ▁>                        | O                    | O
# ▁lor                      | B-EMAIL              | I-EMAIL              ❌
# t                         | I-EMAIL              | I-EMAIL
# iz                        | I-EMAIL              | I-EMAIL
# @                         | I-EMAIL              | I-EMAIL
# example                   | I-EMAIL              | I-EMAIL
# .                         | I-EMAIL              | I-EMAIL
# com                       | I-EMAIL              | I-EMAIL
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁                         | O                    | O
# EMAIL                     | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁GI                       | O                    | O
# VEN                       | O                    | O
# NAME                      | O                    | O
# ▁>                        | O                    | O
# ▁Maria                    | B-GIVENNAME          | O                    ❌
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁GI                       | O                    | O
# VEN                       | O                    | O
# NAME                      | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁ID                       | O                    | O
# CARD                      | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁182                      | B-IDCARDNUM          | I-SOCIALNUM          ❌
# -55                       | I-IDCARDNUM          | I-SOCIALNUM          ❌
# -32                       | I-IDCARDNUM          | I-SOCIALNUM          ❌
# 52                        | I-IDCARDNUM          | I-SOCIALNUM          ❌
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁ID                       | O                    | O
# CARD                      | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# PASSWORD                  | O                    | O
# ▁>                        | O                    | O
# ▁#                        | B-PASSWORD           | O                    ❌
# ip                        | I-PASSWORD           | O                    ❌
# B                         | I-PASSWORD           | O                    ❌
# k                         | I-PASSWORD           | O                    ❌
# 5*                        | I-PASSWORD           | O                    ❌
# C                         | I-PASSWORD           | O                    ❌
# $                         | I-PASSWORD           | O                    ❌
# 5                         | I-PASSWORD           | O                    ❌
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁                         | O                    | O
# PASSWORD                  | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# SOCIAL                    | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁21                       | B-SOCIALNUM          | I-SOCIALNUM          ❌
# 7-8                       | I-SOCIALNUM          | I-SOCIALNUM
# 8-0                       | I-SOCIALNUM          | I-SOCIALNUM
# 992                       | I-SOCIALNUM          | I-SOCIALNUM
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁                         | O                    | O
# SOCIAL                    | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁ST                       | O                    | O
# REET                      | O                    | O
# ▁>                        | O                    | O
# ▁                         | B-STREET             | I-ADDRESS            ❌
# Raymond                   | I-STREET             | I-ADDRESS            ❌
# ▁Trail                    | I-STREET             | I-ADDRESS            ❌
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁ST                       | O                    | O
# REET                      | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁SUR                      | O                    | O
# NAME                      | O                    | O
# ▁>                        | O                    | O
# ▁Hawk                     | B-SURNAME            | O                    ❌
# ins                       | I-SURNAME            | O                    ❌
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁SUR                      | O                    | O
# NAME                      | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# TAX                       | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁928                      | B-TAXNUM             | I-SOCIALNUM          ❌
# -98                       | I-TAXNUM             | I-SOCIALNUM          ❌
# -                         | I-TAXNUM             | I-SOCIALNUM          ❌
# 3296                      | I-TAXNUM             | I-SOCIALNUM          ❌
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁                         | O                    | O
# TAX                       | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁TELE                     | O                    | O
# PHONE                     | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁+1                       | B-TELEPHONENUM       | I-TELEPHONENUM       ❌
# -                         | I-TELEPHONENUM       | I-TELEPHONENUM
# 621                       | I-TELEPHONENUM       | I-TELEPHONENUM
# -57                       | I-TELEPHONENUM       | I-TELEPHONENUM
# 2-5                       | I-TELEPHONENUM       | I-TELEPHONENUM
# 811                       | I-TELEPHONENUM       | I-TELEPHONENUM
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁TELE                     | O                    | O
# PHONE                     | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# USER                      | O                    | O
# NAME                      | O                    | O
# ▁>                        | O                    | O
# ▁                         | B-USERNAME           | O                    ❌
# rf                        | I-USERNAME           | O                    ❌
# inley                     | I-USERNAME           | O                    ❌
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁                         | O                    | O
# USER                      | O                    | O
# NAME                      | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# ZIP                       | O                    | O
# CODE                      | O                    | O
# ▁>                        | O                    | O
# ▁99                       | B-ZIPCODE            | O                    ❌
# 826                       | I-ZIPCODE            | O                    ❌
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁                         | O                    | O
# ZIP                       | O                    | O
# CODE                      | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁data                     | O                    | O
# ▁>                        | O                    | O
# ================================================================================
#
#
# ==================== Эпоха 4/20 (λ=158.74) ====================
#   Эпоха 4, Шаг 50/68: Loss=1.0046, Acc=0.8121, Penalty=0.0002
# Конец эпохи 4: Avg Loss: 1.0675, Avg Acc: 0.8062, Avg Penalty: 0.0010
# Тестовые метрики: Loss=0.7767, Acc=0.8231, F1=0.7875
#
# ============================== СЛУЧАЙНЫЙ ТЕСТОВЫЙ ПРИМЕР ==============================
# Токен                     | Истинная метка       | Предсказание
# ----------------------------------------------------------------------
# ▁{                        | O                    | O
# ▁"                        | O                    | O
# ▁user                     | O                    | O
# _                         | O                    | O
# name                      | O                    | O
# ▁"                        | O                    | O
# ▁                         | O                    | O
# :                         | O                    | O
# ▁"                        | O                    | O
# ▁Heather                  | B-PERSON             | O                    ❌
# ▁"                        | O                    | O
# ▁"                        | O                    | O
# ▁Lane                     | I-PERSON             | O                    ❌
# ▁"                        | O                    | O
# ▁                         | O                    | O
# ,                         | O                    | O
# ▁"                        | O                    | O
# ▁contact                  | O                    | O
# _                         | O                    | O
# email                     | O                    | O
# ▁"                        | O                    | O
# ▁                         | O                    | O
# :                         | O                    | O
# ▁"                        | O                    | O
# ▁jo                       | B-EMAIL              | I-EMAIL              ❌
# nathan                    | I-EMAIL              | I-EMAIL
# well                      | I-EMAIL              | I-EMAIL
# s                         | I-EMAIL              | I-EMAIL
# @                         | I-EMAIL              | I-EMAIL
# example                   | I-EMAIL              | I-EMAIL
# .                         | I-EMAIL              | I-EMAIL
# net                       | I-EMAIL              | I-EMAIL
# ▁"                        | O                    | O
# ▁                         | O                    | O
# ,                         | O                    | O
# ▁"                        | O                    | O
# ▁phone                    | O                    | O
# ▁"                        | O                    | O
# ▁                         | O                    | O
# :                         | O                    | O
# ▁"                        | O                    | O
# ▁+1                       | B-PHONE              | I-TELEPHONENUM       ❌
# -                         | I-PHONE              | I-TELEPHONENUM       ❌
# 901                       | I-PHONE              | I-TELEPHONENUM       ❌
# -98                       | I-PHONE              | I-TELEPHONENUM       ❌
# 0-0                       | I-PHONE              | I-TELEPHONENUM       ❌
# 662                       | I-PHONE              | I-TELEPHONENUM       ❌
# x                         | I-PHONE              | I-TELEPHONENUM       ❌
# 64                        | I-PHONE              | I-TELEPHONENUM       ❌
# 685                       | I-PHONE              | I-TELEPHONENUM       ❌
# ▁"                        | O                    | O
# ▁                         | O                    | O
# ,                         | O                    | O
# ▁"                        | O                    | O
# ▁last                     | O                    | O
# _                         | O                    | O
# login                     | O                    | O
# _                         | O                    | O
# ip                        | O                    | O
# ▁"                        | O                    | O
# ▁                         | O                    | O
# :                         | O                    | O
# ▁"                        | O                    | O
# ▁14                       | B-IP_ADDRESS         | I-SOCIALNUM          ❌
# 2.24                      | I-IP_ADDRESS         | I-SOCIALNUM          ❌
# 3.19                      | I-IP_ADDRESS         | I-SOCIALNUM          ❌
# 1.78                      | I-IP_ADDRESS         | I-IP_ADDRESS
# ▁"                        | O                    | O
# ▁                         | O                    | O
# ,                         | O                    | O
# ▁"                        | O                    | O
# ▁home                     | O                    | O
# _                         | O                    | O
# address                   | O                    | O
# ▁"                        | O                    | O
# ▁                         | O                    | O
# :                         | O                    | O
# ▁"                        | O                    | O
# ▁85                       | B-ADDRESS            | O                    ❌
# 690                       | I-ADDRESS            | O                    ❌
# ▁"                        | O                    | O
# ▁"                        | O                    | O
# ▁Stevens                  | I-ADDRESS            | I-ADDRESS
# ▁"                        | O                    | O
# ▁"                        | O                    | O
# ▁                         | I-ADDRESS            | I-ADDRESS
# Junction                  | I-ADDRESS            | I-ADDRESS
# s                         | I-ADDRESS            | I-ADDRESS
# ▁"                        | O                    | O
# ▁"                        | O                    | O
# ▁Suite                    | I-ADDRESS            | O                    ❌
# ▁"                        | O                    | O
# ▁"                        | O                    | O
# ▁310                      | I-ADDRESS            | O                    ❌
# ▁"                        | O                    | O
# ▁"                        | O                    | O
# ▁Wilson                   | I-ADDRESS            | I-ADDRESS
# ville                     | I-ADDRESS            | I-ADDRESS
# ,                         | I-ADDRESS            | O                    ❌
# ▁"                        | O                    | O
# ▁"                        | O                    | O
# ▁ME                       | I-ADDRESS            | I-ADDRESS
# ▁"                        | O                    | O
# ▁"                        | O                    | O
# ▁08                       | I-ADDRESS            | O                    ❌
# 440                       | I-ADDRESS            | O                    ❌
# ▁"                        | O                    | O
# ▁}                        | O                    | O
# ================================================================================
#
#
# ==================== Эпоха 5/20 (λ=211.32) ====================
#   Эпоха 5, Шаг 50/68: Loss=0.9655, Acc=0.8205, Penalty=0.0005
# Конец эпохи 5: Avg Loss: 0.9889, Avg Acc: 0.8167, Avg Penalty: 0.0009
# ...
# ▁C                        | O                    | O
# REDIT                     | O                    | O
# CARD                      | O                    | O
# N                         | O                    | O
# UMBER                     | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# DATE                      | O                    | O
# OF                        | O                    | O
# BIR                       | O                    | O
# TH                        | O                    | O
# ▁>                        | O                    | O
# ▁1979                     | B-DATEOFBIRTH        | O                    ❌
# -06-20                    | I-DATEOFBIRTH        | O                    ❌
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁                         | O                    | O
# DATE                      | O                    | O
# OF                        | O                    | O
# BIR                       | O                    | O
# TH                        | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# DRIVER                    | O                    | O
# LIC                       | O                    | O
# ENSE                      | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁70                       | B-DRIVERLICENSENUM   | O                    ❌
# YW                        | I-DRIVERLICENSENUM   | O                    ❌
# 1                         | I-DRIVERLICENSENUM   | O                    ❌
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁                         | O                    | O
# DRIVER                    | O                    | O
# LIC                       | O                    | O
# ENSE                      | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# EMAIL                     | O                    | O
# ▁>                        | O                    | O
# ▁brown                    | B-EMAIL              | I-EMAIL              ❌
# p                         | I-EMAIL              | I-EMAIL
# amela                     | I-EMAIL              | I-EMAIL
# @                         | I-EMAIL              | I-EMAIL
# example                   | I-EMAIL              | I-EMAIL
# .                         | I-EMAIL              | I-EMAIL
# com                       | I-EMAIL              | I-EMAIL
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁                         | O                    | O
# EMAIL                     | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁GI                       | O                    | O
# VEN                       | O                    | O
# NAME                      | O                    | O
# ▁>                        | O                    | O
# ▁                         | B-GIVENNAME          | I-GIVENNAME          ❌
# Rachel                    | I-GIVENNAME          | I-GIVENNAME
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁GI                       | O                    | O
# VEN                       | O                    | O
# NAME                      | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁ID                       | O                    | O
# CARD                      | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁387                      | B-IDCARDNUM          | I-IDCARDNUM          ❌
# -14-                      | I-IDCARDNUM          | I-IDCARDNUM
# 3                         | I-IDCARDNUM          | I-IDCARDNUM
# 298                       | I-IDCARDNUM          | I-IDCARDNUM
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁ID                       | O                    | O
# CARD                      | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# PASSWORD                  | O                    | O
# ▁>                        | O                    | O
# ▁                         | B-PASSWORD           | I-PASSWORD           ❌
# i                         | I-PASSWORD           | I-PASSWORD
# S                         | I-PASSWORD           | I-PASSWORD
# _                         | I-PASSWORD           | I-PASSWORD
# 7+                        | I-PASSWORD           | I-PASSWORD
# VL                        | I-PASSWORD           | I-PASSWORD
# j                         | I-PASSWORD           | I-PASSWORD
# )                         | I-PASSWORD           | I-PASSWORD
# 6                         | I-PASSWORD           | I-PASSWORD
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁                         | O                    | O
# PASSWORD                  | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# SOCIAL                    | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁405                      | B-SOCIALNUM          | I-SOCIALNUM          ❌
# -08-21                    | I-SOCIALNUM          | I-IDCARDNUM          ❌
# 52                        | I-SOCIALNUM          | I-SOCIALNUM
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁                         | O                    | O
# SOCIAL                    | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁ST                       | O                    | O
# REET                      | O                    | O
# ▁>                        | O                    | O
# ▁Garcia                   | B-STREET             | I-ADDRESS            ❌
# ▁Rapid                    | I-STREET             | I-STREET
# s                         | I-STREET             | I-STREET
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁ST                       | O                    | O
# REET                      | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁SUR                      | O                    | O
# NAME                      | O                    | O
# ▁>                        | O                    | O
# ▁Ir                       | B-SURNAME            | I-SURNAME            ❌
# win                       | I-SURNAME            | I-SURNAME
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁SUR                      | O                    | O
# NAME                      | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# TAX                       | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁928                      | B-TAXNUM             | I-TAXNUM             ❌
# -78                       | I-TAXNUM             | I-TAXNUM
# -57                       | I-TAXNUM             | I-TAXNUM
# 05                        | I-TAXNUM             | I-TAXNUM
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁                         | O                    | O
# TAX                       | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁TELE                     | O                    | O
# PHONE                     | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁+1                       | B-TELEPHONENUM       | I-TELEPHONENUM       ❌
# -                         | I-TELEPHONENUM       | I-TELEPHONENUM
# 518                       | I-TELEPHONENUM       | I-TELEPHONENUM
# -80                       | I-TELEPHONENUM       | I-TELEPHONENUM
# 6-9                       | I-TELEPHONENUM       | I-TELEPHONENUM
# 830                       | I-TELEPHONENUM       | I-TELEPHONENUM
# x                         | I-TELEPHONENUM       | I-TELEPHONENUM
# 3615                      | I-TELEPHONENUM       | I-TELEPHONENUM
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁TELE                     | O                    | O
# PHONE                     | O                    | O
# NUM                       | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# USER                      | O                    | O
# NAME                      | O                    | O
# ▁>                        | O                    | O
# ▁                         | B-USERNAME           | I-USERNAME           ❌
# tkan                      | I-USERNAME           | I-USERNAME
# e                         | I-USERNAME           | I-USERNAME
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁                         | O                    | O
# USER                      | O                    | O
# NAME                      | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# ZIP                       | O                    | O
# CODE                      | O                    | O
# ▁>                        | O                    | O
# ▁08                       | B-ZIPCODE            | O                    ❌
# 694                       | I-ZIPCODE            | I-ADDRESS            ❌
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁                         | O                    | O
# ZIP                       | O                    | O
# CODE                      | O                    | O
# ▁>                        | O                    | O
# ▁<                        | O                    | O
# ▁                         | O                    | O
# /                         | O                    | O
# ▁data                     | O                    | O
# ▁>                        | O                    | O
# ================================================================================
# Графики сохранены в training_plots.pdf
# Сохранение модели...
# Обучение завершено!
